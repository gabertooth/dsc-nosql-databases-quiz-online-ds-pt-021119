# %% [markdown]
# # NoSQL Databases - Quiz
#
#
# ## Introduction
#
# In this lesson, we'll try our luck with some common open-ended interview questions about NoSQL databases.
#
#
# ## Question 1
#
# What is the difference between a NoSQL and a SQL database?  Which is better?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# NoSQL is used for information that is too complex or does not make sense to store in a relational database. One is not better than the other. It all depends on the kind of data we have and what makes more logical sense.  Some data is stored in formats that fit NoSQL better than SQL. For example, graph databses are a kind of NoSQL. These use nodes or edges and are common among social media apps. Each node carries metadata and represents say one of your connections or friends.
#
#
#
#
#
# ## Question 2
#
# Describe a situation where a NoSQL database might be a better choice than a relational database, and explain your reasoning.
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
#
# ## Question 3
#
# How does MongoDB work? How is it different from a relational database?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# MongoDB is a document store database meaning it keeps records as unique documents within the database. The documents can then contain other files inside of them sort of acting like folders. Each document can have its own unique layout with different keys and values.
#
#
#
#
#
#
# ## Question 4
#
# What is fault tolerance, and what does it have to do with Resilient Distributed Datasets?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# This deals with RDD where when we query a database we want to make sure that the data we get back is complete. The way to prevent this is through having RDD where the information stores backups of other servers data on its own so when one server goes down the other server acts as a back up to present the full data set to the consumer.
#
#
#
#
#
#
# ## Question 5
#
# What is MapReduce? How is it related to Hadoop?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# It is essentially having a bunch of servers run seperate queries and then bringing them together to form one massive query.
#
#
# ## Summary
#
#
# In this lesson, we reviewed some common NoSQL interview questions.
